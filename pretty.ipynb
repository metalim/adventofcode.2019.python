# %%
drawsymbols = '☕♈♉♊♋♌♍♎♏♐♑♒♓♿⚪⚫⚽⛅⛔⛪⛳⛵⛺✨❌❎➰➿⬛⬜⭐⭕'
for c in drawsymbols:
    print(c*10)
# Out:
# ☕☕☕☕☕☕☕☕☕☕
# ♈♈♈♈♈♈♈♈♈♈
# ♉♉♉♉♉♉♉♉♉♉
# ♊♊♊♊♊♊♊♊♊♊
# ♋♋♋♋♋♋♋♋♋♋
# ♌♌♌♌♌♌♌♌♌♌
# ♍♍♍♍♍♍♍♍♍♍
# ♎♎♎♎♎♎♎♎♎♎
# ♏♏♏♏♏♏♏♏♏♏
# ♐♐♐♐♐♐♐♐♐♐
# ♑♑♑♑♑♑♑♑♑♑
# ♒♒♒♒♒♒♒♒♒♒
# ♓♓♓♓♓♓♓♓♓♓
# ♿♿♿♿♿♿♿♿♿♿
# ⚪⚪⚪⚪⚪⚪⚪⚪⚪⚪
# ⚫⚫⚫⚫⚫⚫⚫⚫⚫⚫
# ⚽⚽⚽⚽⚽⚽⚽⚽⚽⚽
# ⛅⛅⛅⛅⛅⛅⛅⛅⛅⛅
# ⛔⛔⛔⛔⛔⛔⛔⛔⛔⛔
# ⛪⛪⛪⛪⛪⛪⛪⛪⛪⛪
# ⛳⛳⛳⛳⛳⛳⛳⛳⛳⛳
# ⛵⛵⛵⛵⛵⛵⛵⛵⛵⛵
# ⛺⛺⛺⛺⛺⛺⛺⛺⛺⛺
# ✨✨✨✨✨✨✨✨✨✨
# ❌❌❌❌❌❌❌❌❌❌
# ❎❎❎❎❎❎❎❎❎❎
# ➰➰➰➰➰➰➰➰➰➰
# ➿➿➿➿➿➿➿➿➿➿
# ⬛⬛⬛⬛⬛⬛⬛⬛⬛⬛
# ⬜⬜⬜⬜⬜⬜⬜⬜⬜⬜
# ⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐
# ⭕⭕⭕⭕⭕⭕⭕⭕⭕⭕
